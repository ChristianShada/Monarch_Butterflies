# %%
#Import Dependencies
import pandas as pd
import os
import csv

# %%
#Load data sets
MW2017= pd.read_csv("Monarch_Watch_2017.csv")
MW2018= pd.read_csv("Monarch_Watch_2018.csv")
MW2019= pd.read_csv("Monarch_Watch_2019.csv")
MW2020= pd.read_csv("Monarch_Watch_2020.csv")

# %%
MW2020DROP= MW2020.drop(columns=['Notes'])

# %%
MW2020DROP
# Out:
#     Tag Code        Date      City/Location State/Province   ZIP/PC Country  \
# 0    AABX630  10/22/2020     North Cape May             NJ     8204     USA
# 1    AABX693   9/30/2020             Sewell             NJ     8080     USA
# 2    AAHL099   9/26/2020      Saint-Lambert             QC  J4p 2j4     CAN
# 3    AAHL209  10/10/2020        Quebec City             QC  G1S 3J3     CAN
# 4    AAJM336   8/26/2020         Wilmington             NC    28403     USA
# ..       ...         ...                ...            ...      ...     ...
# 872   YEB316  10/13/2020       Hillsborough             NC    27278     USA
# 873   ZCU167   9/26/2020            Livonia             MI    48154     USA
# 874   ZCU176   8/30/2020  Harrison township             MI    48045     USA
# 875   ZCU183    9/4/2020          Baltimore             MI    48047     USA
# 876   ZCU197   8/31/2020            Milford             MI    48357     USA
#
#     First Name
# 0         Mark
# 1       Debbie
# ...
